# %%
from src.algorithms.blind_search import BlindSearch
from src.run import run

run(BlindSearch)
# Out:
# Function: sphere, Algorithm: BlindSearch, Best found solution: 0.0012180013577749657
# Animating step #0
# Animating step #0
# Animating step #1
# Animating step #2
# Animating step #3
# Animating step #4
# Animating step #5
# Animating step #6
# Animating step #7
# Animating step #8
# Animating step #9
# Function: ackley, Algorithm: BlindSearch, Best found solution: 0.9978425680689829
# Animating step #0
# Animating step #0
# Animating step #1
# Animating step #2
# Animating step #3
# Animating step #4
# Animating step #5
# Animating step #6
# Animating step #7
# Animating step #8
# Animating step #9
# Animating step #10
# Animating step #11
# Animating step #12
# Function: rastrigin, Algorithm: BlindSearch, Best found solution: 1.1623073002922055
# Animating step #0
# Animating step #0
# Animating step #1
# Animating step #2
# Animating step #3
# Animating step #4
# Animating step #5
# Animating step #6
# Animating step #7
# Animating step #8
# Animating step #9
# ...

# %% [markdown]
# ![Ackley](../assets/BlindSearch/ackley.gif)
